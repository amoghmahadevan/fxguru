# %%
import sys
sys.path.append("../")
from plotting import CandlePlot
import pandas as pd

# %%
from technicals.patterns import apply_patterns

# %%
df = pd.read_pickle("../data/GBP_JPY_H1.pkl")

# %%
df_an = df[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c']].copy()

# %%
df_an.tail()
# Out:
#                            time    mid_o    mid_h    mid_l    mid_c
# 37219 2021-12-30 19:00:00+00:00  155.312  155.444  155.274  155.444
# 37220 2021-12-30 20:00:00+00:00  155.442  155.470  155.289  155.312
# 37221 2021-12-30 21:00:00+00:00  155.317  155.382  155.286  155.382
# 37222 2021-12-30 22:00:00+00:00  155.353  155.381  155.282  155.329
# 37223 2021-12-30 23:00:00+00:00  155.336  155.360  155.284  155.310

# %%
df_an = apply_patterns(df_an)

# %%
df_an.tail()
# Out:
#                            time    mid_o    mid_h    mid_l    mid_c  \
# 37219 2021-12-30 19:00:00+00:00  155.312  155.444  155.274  155.444
# 37220 2021-12-30 20:00:00+00:00  155.442  155.470  155.289  155.312
# 37221 2021-12-30 21:00:00+00:00  155.317  155.382  155.286  155.382
# 37222 2021-12-30 22:00:00+00:00  155.353  155.381  155.282  155.329
# 37223 2021-12-30 23:00:00+00:00  155.336  155.360  155.284  155.310
#
#        body_lower  body_upper  body_bottom_perc  body_top_perc  body_perc  \
# 37219     155.312     155.444         22.352941     100.000000  77.647059
# 37220     155.312     155.442         12.707182      84.530387  71.823204
# 37221     155.317     155.382         32.291667     100.000000  67.708333
# 37222     155.329     155.353         47.474747      71.717172  24.242424
# 37223     155.310     155.336         34.210526      68.421053  34.210526
#
#        ...  body_perc_prev_2  HANGING_MAN  SHOOTING_STAR  SPINNING_TOP  \
# 37219  ...         86.390533        False          False         False
# 37220  ...         12.337662        False          False         False
# 37221  ...         77.647059        False          False         False
# 37222  ...         71.823204        False          False         False
# 37223  ...         67.708333        False          False         False
#
#        MARUBOZU  ENGULFING  TWEEZER_TOP  TWEEZER_BOTTOM  MORNING_STAR  \
# 37219     False       True        False           False         False
# 37220     False      False        False           False         False
# 37221     False      False        False           False         False
# 37222     False      False        False           False         False
# 37223     False      False        False           False         False
#
#        EVENING_STAR
# 37219         False
# 37220         False
# 37221         False
# 37222         False
# 37223         False
#
# [5 rows x 31 columns]

# %%
import plotly.graph_objects as go

# %%
MARKER = '#0066FF'
dfp = df_an.iloc[600:800]
cp = CandlePlot(dfp, candles=True)
df_temp = cp.df_plot[cp.df_plot.MARUBOZU == True]
cp.fig.add_trace(go.Candlestick(
                x = df_temp.sTime,
                open = df_temp.mid_o,
                high = df_temp.mid_h,
                low = df_temp.mid_l,
                close = df_temp.mid_c,
                line = dict(width=1), opacity=1,
                increasing_fillcolor = MARKER,
                decreasing_fillcolor = MARKER,
                increasing_line_color = MARKER,
                decreasing_line_color = MARKER
            ))
cp.fig.update_yaxes(
            gridcolor = "#1f292f"
)
cp.fig.update_xaxes(
    gridcolor = "#1f292f",
    rangeslider = dict(visible = False),
    nticks = 5
)
cp.fig.update_layout(
    width = 825,
    height = 400,
    margin = dict(l=10, r=10, b=10, t=10),
    paper_bgcolor="#2c303c",
    plot_bgcolor="#2c303c",
    font = dict(size=8, color = "#e1e1e1")
)
# Out:
# <div>                            <div id="7b05b5c1-5170-4fe1-b0e5-ff8bc9a241c3" class="plotly-graph-div" style="height:400px; width:825px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b05b5c1-5170-4fe1-b0e5-ff8bc9a241c3")) {                    Plotly.newPlot(                        "7b05b5c1-5170-4fe1-b0e5-ff8bc9a241c3",                        [{"close":[164.136,164.199,164.306,164.016,163.721,163.788,163.516,163.544,161.044,161.01,161.551,160.522,161.58,162.132,162.443,161.499,161.399,161.975,161.994,162.657,162.616,162.759,162.964,162.886,162.658,162.732,162.386,163.472,163.022,162.591,161.946,162.592,163.374,163.6,163.814,163.612,163.604,163.502,163.07,162.962,163.336,163.862,164.514,164.398,164.378,164.248,164.654,165.062,164.392,164.904,165.16,165.46,165.411,165.531,165.458,165.126,164.934,164.888,165.11,164.801,165.119,165.215,165.54,165.486,165.532,165.578,165.571,165.558,165.38,165.412,165.229,165.282,165.638,165.594,165.51,165.743,165.633,165.253,165.15,165.368,165.855,164.691,164.521,164.482,164.071,163.37,162.918,162.836,162.778,162.906,162.774,162.655,162.887,163.195,163.4,163.252,163.384,163.07,163.105,162.618,162.504,162.811,162.292,161.852,162.484,163.261,163.348,163.346,163.388,163.161,162.804,163.578,163.415,163.482,163.04,162.544,162.62,163.064,163.016,163.23,162.816,162.819,162.986,162.98,163.05,162.88,162.538,162.821,162.259,162.731,163.283,163.612,163.512,163.708,163.426,163.256,162.864,162.703,162.68,162.581,162.244,162.435,162.406,162.285,161.66,161.428,161.728,161.639,161.682,162.049,162.088,161.655,162.048,161.417,161.29,161.245,161.166,161.181,161.09,160.9,161.236,161.408,161.448,161.654,161.758,162.169,160.968,160.502,161.392,161.092,161.198,161.251,161.248,161.303,160.854,160.39,159.747,160.296,160.29,160.078,159.447,159.3,159.613,159.708,160.147,160.128,160.112,159.69,159.638,159.774,159.786,159.826,159.393,158.532,158.427,158.19,158.68,158.766,158.194,158.188],"decreasing":{"fillcolor":"#CC2E3C","line":{"color":"#FF3A4C"}},"high":[164.897,164.278,164.41,164.308,164.032,163.877,163.841,163.867,163.548,161.317,161.883,161.658,163.189,162.436,162.485,162.67,162.078,162.017,162.334,162.901,162.902,162.826,163.182,163.01,162.938,162.777,162.726,163.55,163.473,163.199,162.708,162.912,163.564,163.886,164.069,163.928,164.002,163.974,163.602,163.645,163.546,163.949,164.58,164.78,164.498,164.403,164.76,165.093,165.061,165.02,165.218,165.49,165.575,165.642,165.763,165.599,165.276,165.222,165.199,165.212,165.254,165.376,165.6,165.586,165.585,165.59,165.606,165.627,165.656,165.464,165.487,165.387,165.724,165.692,165.708,165.834,165.824,165.651,165.356,165.409,166.096,165.85,164.716,164.617,164.578,164.091,163.56,163.079,162.909,162.956,162.906,162.847,162.905,163.251,163.424,163.428,163.56,163.393,163.227,163.153,162.752,162.869,162.904,162.36,162.584,163.322,163.764,163.417,163.388,163.57,163.43,163.752,163.886,163.59,163.489,163.116,162.75,163.127,163.174,163.244,163.268,162.99,163.056,163.134,163.174,163.204,162.95,163.077,162.828,163.064,163.297,163.86,163.97,163.788,163.786,163.584,163.276,162.918,162.897,162.776,162.68,162.494,162.485,162.516,162.348,161.872,161.786,161.818,161.712,162.171,162.308,162.104,162.174,162.059,161.747,161.474,161.447,161.492,161.338,161.198,161.562,161.558,161.506,161.675,161.814,162.228,161.124,161.032,161.418,161.565,161.222,161.418,161.365,161.422,161.354,160.864,160.594,160.31,160.538,160.374,160.08,159.706,159.906,159.964,160.179,160.333,160.192,160.136,159.767,159.818,159.916,159.932,159.882,159.392,158.73,158.449,158.883,158.828,158.767,158.516],"increasing":{"fillcolor":"#24A06B","line":{"color":"#2EC886"}},"line":{"width":1},"low":[163.916,163.843,164.027,163.966,163.598,163.628,163.124,163.44,160.077,159.814,160.762,160.307,160.154,161.268,162.102,161.443,161.278,161.392,161.892,161.58 ...
